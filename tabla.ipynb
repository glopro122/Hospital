# %% [markdown]
# <a href="https://colab.research.google.com/github/glopro122/Hospital/blob/main/tabla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller de Análisis de Complejidad Algorítmica
# Ian Barrios \
# Osman De La Hoz \
# Keiner Barragán \
# Manuel Gonzalez

# %% [markdown]
# # Ejercicio 1: Complejidad Lineal O(n) - Búsqueda Lineal

# %%
def busqueda_lineal(array, objetivo):
    for i in range(len(array)):
        if array[i] == objetivo:
            return i
    return -1

arr = [7, 9, 10, 12, 1, 0]
valor = 9

resultado = busqueda_lineal(arr, valor)
print("Resultado:", resultado)
# Out:
# Resultado: 1

# %% [markdown]
# # Mejor caso
#
# Ocurre cuando el elemento buscado se encuentra en la primera posición.
#
# - Comparaciones: 1
# - Retorno: 1
#
# $$
# T_{mejor}(n) \in \Theta(1)
# $$
#
#
# #Peor caso
# Ocurre cuando el elemento buscando se encuentra en la posición n del array o no existe.
#
# - Comparaciones n + 1
# - Retorno: 1
#
# $$
# T_{peor}(n) = n + 1
# $$
#
# Eliminando constantes:
#
# $$
# T_{peor}(n) \in \Theta(n)
# $$
#
# # Caso promedio
# Si el elemento buscado se encuentra en la posición k, se realizan k + 1 comparaciones.
#
# El elemento puede estar en cualquiera de las n posiciones del array, entonces:
# $$
# T_{prom}(n) = \frac{1}{n}\sum_{k=0}^{n-1}(k+1)
# $$
#
# Sabemos que:
# $$1 + 2 + 3 + \dots + n = \frac{n(n+1)}{2}
# $$
#
# Entonces:
#
# $$
# T_{prom}(n) = \frac{1}{n} \cdot \frac{n(n+1)}{2}
# $$
#
#
# Simplificando:
#
# $$
# T_{prom}(n) = \frac{n+1}{2}
# $$
#
# Por lo tanto:
#
# $$
# T_{prom}(n) \in \Theta(n)
# $$
#
# # Orden de complejidad al que pertenece
# La búsqueda lineal pertenece al orden de complejidad lineal:
#
# $$
# O(n)
# $$

# %% [markdown]
# # Ejercicio 2: Complejidad Logarítmica O(log n) — Búsqueda Binaria

# %%
def busqueda_binaria(arr, objetivo):
    izquierda = 0
    derecha = len(arr) - 1

    while izquierda <= derecha:
        medio = (izquierda + derecha) // 2

        if arr[medio] == objetivo:
            return medio
        elif arr[medio] < objetivo:
            izquierda = medio + 1
        else:
            derecha = medio - 1

    return -1

# %% [markdown]
# ## Mejor caso
# Ocurre cuando el elemento buscado se encuentra en la mitad del array, en la primera iteración.
#
# $$
# T_{mejor}(n) \in \Theta(1)
# $$
#
# ## Peor caso
# Ocurre cuando el elemento no está o se encuentra en el último nivel de las divisiones del array.
#
# En cada iteración el tamaño del problema se reduce a la mitad:
#
# $$
# \frac{n}{2^k}
# $$
#
# El algoritmo termina cuando el tamaño se reduce a 1:
#
# $$
# \frac{n}{2^k} = 1
# $$
#
# Entonces:
#
# $$n = 2^k$$
#
# Aplicando logaritmo base 2 de ambos lados:
#
# $$k = \log_2(n)$$
#
# Ahora para el peor caso:
#
# $$
# T_{peor}(n) = a\log_2(n) + b
# $$
# \
# ($a$ son las operaciones dentro del while, que se realizarán $log_2(n)$ veces, $b$ son las operaciones que se realizan antes y después del while, se realizan 1 sola vez cada una)
#
#
# Eliminando constantes:
#
# $$
# T_{peor}(n) \in \Theta(\log n)
# $$
#
# ## Caso promedio
#
# En promedio también se requieren aproximadamente $ \log(n) $ iteraciones.
#
# $$
# T_{prom}(n) \in \Theta(\log n)
# $$
#
# ##Orden de complejidad al que pertenece
#
# La búsqueda binaria pertenece al orden de complejidad:
#
# $$
# O(\log n)
# $$

# %% [markdown]
# # Ejercicio 3: Complejidad Cuadrática O(n²) - Ordenamiento Burbuja

# %%
def burbuja(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr

# %% [markdown]
# ## Mejor caso
# Si el array ya está ordenado, solo se recorre una vez.
# \
# La operación principal es $ arr[j] > arr[j + 1].$
#
# $$
# T_{mejor}(n) = n-1
# $$
#
# $$
# T_{mejor}(n) \in \Theta(n)
# $$
#
# ##Peor caso
# Posiciones del array en orden inverso (descendente).
# El número total de comparaciones está dado por:
#
# $$
# T(n) = \sum_{i=0}^{n-1} (n - i - 1)
# $$
# Se recorre el array la mayor cantidad de veces posible, entonces:
# $$
# T_{peor}(n) = \frac{n(n-1)}{2}
# $$
#
# $$
# T_{peor}(n) \in \Theta(n^2)
# $$
#
# ## Caso promedio
#
# El número de comparaciones no depende del orden del array, por lo tanto:
#
# $$
# T_{prom}(n) = \frac{n(n-1)}{2}
# $$
#
# $$
# T_{prom}(n) \in \Theta(n^2)
# $$
#
# ## Orden de complejidad al que pertenece
# El ordenamiento burbuja pertenece al orden de complejidad:
#
# $$
# O(n^2)
# $$

# %% [markdown]
# ## Ejercicio 4: Complejidad Cúbica O(n³) - Multiplicación de Matrices

# %%
def mult_matrices(A, B):
    n = len(A)
    C = [[0 for _ in range(n)] for _ in range(n)]

    for i in range(n):
        for j in range(n):
            suma = 0
            for k in range(n):
                suma += A[i][k] * B[k][j]
            C[i][j] = suma

    return C

# %% [markdown]
# La operación dominante se realiza en el bucle interno:
#
# $$
# suma \mathrel{+}= A[i][k]\cdot B[k][j]
# $$
#
# Conteo de iteraciones:
# - El bucle \(i\) se ejecuta \(n\) veces.
# - El bucle \(j\) se ejecuta \(n\) veces por cada \(i\).
# - El bucle \(k\) se ejecuta \(n\) veces por cada par \((i,j)\).
# \
#
#
# $$
# n \cdot n \cdot n = n^3
# $$
#
# Si las operaciones dentro de cada operación cuestan \(c\):
#
# $$
# T(n) = c\,n^3 + b
# $$
#
# Por lo tanto:
#
# $$
# T(n) \in \Theta(n^3)
# $$
#
# ## Casos
#
# $$
# n \cdot n \cdot n = n^3
# $$
#
# Si las operaciones dentro de cada iteración cuestan \(c\):
#
# $$
# T(n) = c\,n^3 + b
# $$
#
# Por lo tanto:
# $$
# T(n) \in \Theta(n^3)
# $$
#
# ## Orden del complejidad al que pertenece
# La multiplicación de matrices pertenece al orden de complejidad:
# $$\Theta(n^3)$$

# %% [markdown]
# ## Ejercicio 5: Análisis Combinado

# %%
from IPython.display import Image
Image("imagen1.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1288         if self.embed:
#    1289             mimetype = self._mimetype
# -> 1290             data, metadata = self._data_and_metadata(always_both=True)
#    1291             if metadata:
#    1292                 metadata = {mimetype: metadata}
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'imagen1.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_png_(self)
#    1318     def _repr_png_(self):
#    1319         if self.embed and self.format == self._FMT_PNG:
# -> 1320             return self._data_and_metadata()
#    1321
#    1322     def _repr_jpeg_(self):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'imagen1.png'

# %% [markdown]
# # Método del contador
# ## Segmento 1
# El ciclo se ejecuta 100 veces:
#
# $$
# C_1 = 100
# $$
#
# ---
#
# ## Segmento 2
#
# Dos bucles anidados:
#
# - El bucle externo se ejecuta \(n\) veces.
# - El bucle interno se ejecuta \(n\) veces por cada iteración del externo.
#
# Total:
#
# $$
# C_2 = n \cdot n = n^2
# $$
#
# ---
# ## Segmento 3
#
# El ciclo se ejecuta \(n\) veces:
#
# $$
# C_3 = n
# $$

# %% [markdown]
# # Expresión Completa
#
# Sumamos los tres segmentos:
#
# $$
# T(n) = 100 + n^2 + n
# $$
#
# Aplicando la regla de la suma, el término dominante es:
#
# $$
# n^2
# $$
# Por lo tanto:
#
# $$
# T(n) \in \Theta(n^2)
# $$
#
# ## Orden de complejidad final:
#
# $$
# O(n^2)
# $$

# %% [markdown]
# ## Parte experimental:

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# #Funcion tabla:

# %%
import math
import pandas as pd

def construir_tabla(resultados):
    """
    resultados: lista de dicts con llaves:
      Algoritmo, n, Tiempo (s), Contador
    """
    filas = []
    for r in resultados:
        n = r["n"]
        t = r["Tiempo (s)"]

        filas.append({
            "Algoritmo": r["Algoritmo"],
            "n": n,
            "Tiempo (s)": t,
            "Contador": r["Contador"],
            "Tiempo/n": t / n,
            "Tiempo/n²": t / (n**2),
            "Tiempo/n³": t / (n**3),
            "Tiempo/log n": t / (math.log(n) if n > 1 else float("nan"))
        })

    df = pd.DataFrame(filas, columns=[
        "Algoritmo","n","Tiempo (s)","Contador","Tiempo/n","Tiempo/n²","Tiempo/n³","Tiempo/log n"
    ])

    # (Opcional) dejar el nombre del algoritmo solo en la primera fila del bloque
    df2 = df.copy()
    for alg in df2["Algoritmo"].unique():
        idx = df2.index[df2["Algoritmo"] == alg].tolist()
        for i in idx[1:]:
            df2.loc[i, "Algoritmo"] = ""
    return df2

# %% [markdown]
# #Funcion medir_tiempo:

# %%
#Implementación:
import time
import matplotlib.pyplot as plt
import random
import math

def medir_tiempo(algoritmos, *args):
  inicio = time.perf_counter()
  contador = algoritmos(*args)
  fin = time.perf_counter()
  return fin - inicio, contador

# %% [markdown]
# # Experimento busqueda lineal O(n):

# %%
tamaños = [10, 50, 100, 500, 1000, 5000]

tiempos_experimentales = []
contadores = []

resultados_tabla = []  # <-- nuevo: acumulamos para la tabla

for n in tamaños:

    tiempos = []
    contador_rep = None

    for _ in range(5):  # repetir 5 veces
        arr = [random.randint(1, 10000) for _ in range(n)]
        objetivo = arr[-1]  # "peor caso"

        tiempo, contador = medir_tiempo(busqueda_lineal, arr, objetivo)
        tiempos.append(tiempo)
        contador_rep = contador

    tiempo_promedio = sum(tiempos) / 5

    tiempos_experimentales.append(tiempo_promedio)
    contadores.append(contador_rep)

    # <-- nuevo: guardar para tabla SOLO los n pedidos
    if n in [100, 1000, 5000]:
        resultados_tabla.append({
            "Algoritmo": "Lineal",
            "n": n,
            "Tiempo (s)": tiempo_promedio,
            "Contador": contador_rep
        })

    print(f"n = {n}")
    print(f"Tiempo promedio = {tiempo_promedio}")
    print(f"Contador = {contador_rep}")
    print("-----------")
# Out:
# n = 10
# Tiempo promedio = 1.6781999988779718e-06
# Contador = 9
# -----------
# n = 50
# Tiempo promedio = 3.3344000030410827e-06
# Contador = 49
# -----------
# n = 100
# Tiempo promedio = 6.50820001055763e-06
# Contador = 99
# -----------
# n = 500
# Tiempo promedio = 3.350839997438015e-05
# Contador = 499
# -----------
# n = 1000
# Tiempo promedio = 7.04541999994035e-05
# Contador = 999
# -----------
# n = 5000
# Tiempo promedio = 0.00024190020000105505
# Contador = 4999
# -----------

# %% [markdown]
# #Experimento Busqueda Binaria O(log(n))

# %%
tamaños_binaria = [10, 50, 100, 500, 1000, 2000, 5000]

tiempos_binaria = []
contadores_binaria = []

for n in tamaños_binaria:

    tiempos = []
    contador_rep = None

    for _ in range(5):
        arr = sorted([random.randint(1, 10000) for _ in range(n)])  # ordenado
        objetivo = arr[-1]  # peor caso

        tiempo, contador = medir_tiempo(busqueda_binaria, arr, objetivo)
        tiempos.append(tiempo)
        contador_rep = contador

    tiempo_promedio = sum(tiempos) / 5

    tiempos_binaria.append(tiempo_promedio)
    contadores_binaria.append(contador_rep)

    if n in [100, 1000, 5000]:
        resultados_tabla.append({
            "Algoritmo": "Binaria",
            "n": n,
            "Tiempo (s)": tiempo_promedio,
            "Contador": contador_rep
        })

    print(f"[Binaria] n = {n}")
    print(f"Tiempo promedio = {tiempo_promedio}")
    print(f"Contador = {contador_rep}")
    print("----------------------")
# Out:
# [Binaria] n = 10
# Tiempo promedio = 1.6386000083912222e-06
# Contador = 9
# ----------------------
# [Binaria] n = 50
# Tiempo promedio = 9.37600020733953e-07
# Contador = 49
# ----------------------
# [Binaria] n = 100
# Tiempo promedio = 9.641999895393384e-07
# Contador = 99
# ----------------------
# [Binaria] n = 500
# Tiempo promedio = 4.5971999952598704e-06
# Contador = 499
# ----------------------
# [Binaria] n = 1000
# Tiempo promedio = 3.2410000130767004e-06
# Contador = 999
# ----------------------
# [Binaria] n = 2000
# Tiempo promedio = 3.043000015168218e-06
# Contador = 1999
# ----------------------
# [Binaria] n = 5000
# Tiempo promedio = 4.004999993867386e-06
# Contador = 4999
# ----------------------

# %% [markdown]
# #Experimento ordenamiento burbuja (O(n^2))

# %%
tamaños_burbuja = [10, 50, 100, 200, 500, 1000, 2000]

tiempos_burbuja = []
contadores_burbuja = []

for n in tamaños_burbuja:

    tiempos = []
    contador_rep = None

    for _ in range(5):
        arr = [random.randint(1, 10000) for _ in range(n)]  # desordenado

        # pasar copia si tu algoritmo modifica el arreglo (burbuja lo modifica)
        tiempo, contador = medir_tiempo(burbuja, arr.copy())
        tiempos.append(tiempo)
        contador_rep = contador

    tiempo_promedio = sum(tiempos) / 5

    tiempos_burbuja.append(tiempo_promedio)
    contadores_burbuja.append(contador_rep)

    if n in [100, 1000, 2000]:
        resultados_tabla.append({
            "Algoritmo": "Burbuja",
            "n": n,
            "Tiempo (s)": tiempo_promedio,
            "Contador": contador_rep
        })

    print(f"[Burbuja] n = {n}")
    print(f"Tiempo promedio = {tiempo_promedio}")
    print(f"Contador = {contador_rep}")
    print("----------------------")
# Out:
# [Burbuja] n = 10
# Tiempo promedio = 6.474999986494368e-06
# Contador = [177, 3645, 3703, 4500, 6126, 6618, 7270, 8396, 8625, 9997]
# ----------------------
# [Burbuja] n = 50
# Tiempo promedio = 9.39987999799996e-05
# Contador = [35, 222, 287, 303, 369, 478, 562, 598, 659, 889, 1151, 1462, 1497, 1542, 1630, 1800, 1996, 2081, 2385, 2724, 2850, 3040, 3098, 3129, 3194, 3704, 4192, 4559, 4888, 5072, 5168, 5337, 5526, 6305, 6472, 6641, 7055, 7167, 7824, 7831, 7868, 8687, 8696, 8770, 8976, 9112, 9233, 9519, 9602, 9610]
# ----------------------
# [Burbuja] n = 100
# Tiempo promedio = 0.0004189905999965049
# Contador = [115, 196, 249, 353, 360, 545, 749, 868, 1000, 1434, 1564, 1739, 1857, 1907, 2071, 2142, 2193, 2252, 2271, 2311, 2329, 2370, 2409, 2412, 2415, 2967, 3046, 3174, 3211, 3259, 3331, 3501, 3636, 3737, 3857, 3860, 4035, 4046, 4049, 4088, 4090, 4296, 4348, 4462, 4538, 4697, 4756, 4791, 4984, 5055,
3018, 3020, 3030, 3042, 3046, 3050, 3055, 3055, 3057, 3060, 3063, 3072, 3080, 3082, 3087, 3094, 3094, 3096, 3097, 3104, 3105, 3109, 3112, 3115, 3116, 3117, 3121, 3126, 3127, 3130, 3131, 3134, 3137, 3148, 3152, 3153, 3160, 3161, 3162, 3166, 3173, 3189, 3199, 3201, 3201, 3205, 3207, 3213, 3218, 3219, 3223, 3224, 3227, 3234, 3254, 3265, 3267, 3270, 3271, 3277, 3282, 3285, 3289, 3291, 3297, 3299, 3301, 3308, 3310, 3311, 3311, 3313, 3314, 3327, 3328, 3346, 3356, 3358, 3386, 3389, 3393, 3394, 3396, 3400, 3401, 3405, 3406, 3415, 3417, 3420, 3422, 3425, 3426, 3427, 3432, 3439, 3441, 3447, 3461, 3474, 3481, 3481, 3484, 3488, 3495, 3496, 3498, 3499, 3502, 3506, 3513, 3514, 3527, 3528, 3533, 3533, 3538, 3545, 3547, 3554, 3555, 3560, 3565, 3566, 3571, 3581, 3582, 3587, 3588, 3598, 3599, 3603, 3614, 3617, 3617, 3619, 3621, 362 ...
# ----------------------

# %% [markdown]
# #Experimento Matrices O(n^3)

# %%
tamaños_matrices = [10, 20, 30, 50, 70, 100]

tiempos_matrices = []
contadores_matrices = []

for n in tamaños_matrices:

    tiempos = []
    contador_rep = None

    for _ in range(5):
        A = [[random.randint(1,10) for _ in range(n)] for _ in range(n)]
        B = [[random.randint(1,10) for _ in range(n)] for _ in range(n)]

        tiempo, contador = medir_tiempo(mult_matrices, A, B)
        tiempos.append(tiempo)
        contador_rep = contador

    tiempo_promedio = sum(tiempos) / 5

    tiempos_matrices.append(tiempo_promedio)
    contadores_matrices.append(contador_rep)

    if n in [10, 30, 50]:
        resultados_tabla.append({
            "Algoritmo": "Matrices",
            "n": n,
            "Tiempo (s)": tiempo_promedio,
            "Contador": contador_rep
        })

    print(f"[Matrices] n = {n}")
    print(f"Tiempo promedio = {tiempo_promedio}")
    print(f"Contador = {contador_rep}")
    print("----------------------")
# Out:
# [Matrices] n = 10
# Tiempo promedio = 0.00013725900000736147
# Contador = [[246, 332, 390, 340, 232, 350, 336, 415, 281, 284], [273, 322, 426, 337, 286, 385, 399, 469, 379, 391], [271, 270, 372, 305, 202, 332, 340, 400, 237, 272], [215, 314, 346, 318, 233, 352, 271, 376, 267, 287], [296, 328, 356, 390, 302, 392, 332, 385, 371, 375], [263, 327, 349, 369, 281, 348, 377, 383, 309, 281], [286, 360, 404, 394, 268, 380, 378, 438, 286, 320], [287, 332, 371, 358, 242, 377, 308, 387, 337, 302], [332, 349, 368, 421, 340, 401, 409, 402, 395, 381], [302, 318, 400, 364, 266, 388, 352, 424, 356, 344]]
# ----------------------
# [Matrices] n = 20
# Tiempo promedio = 0.0010452547999875606
# Contador = [[462, 640, 424, 621, 460, 522, 518, 424, 383, 475, 305, 506, 497, 528, 363, 405, 415, 369, 357, 470], [599, 793, 610, 796, 600, 659, 666, 538, 530, 595, 600, 712, 691, 686, 496, 557, 535, 576, 532, 630], [481, 650, 525, 703, 490, 499, 493, 424, 503, 509, 500, 663, 577, 598, 481, 484, 478, 489, 423, 561], [582, 805, 595, 844, 557, 735, 610, 582, 549, 633, 608, 730, 684, 683, 479, 555, 550, 547, 591, 628], [541, 720, 581, 772, 613, 657, 646, 505, 532, 665, 594, 780, 706, 652, 467, 562, 465, 489, 532, 673], [552, 620, 450, 681, 471, 656, 554, 410, 475,