# %% [markdown]
# <a href="https://colab.research.google.com/github/glopro122/Hospital/blob/main/tabla3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller de Análisis de Complejidad Algorítmica
# Ian Barrios \
# Osman De La Hoz \
# Keiner Barragán \
# Manuel Gonzalez

# %% [markdown]
# # Ejercicio 1: Complejidad Lineal O(n) - Búsqueda Lineal

# %%
def busqueda_lineal(array, objetivo):
    contador = 0
    for i in range(len(array)):
        contador += 1
        if array[i] == objetivo:
            return contador
    return contador

arr = [7, 9, 10, 12, 1, 0]
valor = 9

resultado = busqueda_lineal(arr, valor)
print("Resultado:", resultado)
# Out:
# Resultado: 2

# %% [markdown]
# # Mejor caso
#
# Ocurre cuando el elemento buscado se encuentra en la primera posición.
#
# - Comparaciones: 1
# - Retorno: 1
#
# $$
# T_{mejor}(n) \in \Theta(1)
# $$
#
#
# #Peor caso
# Ocurre cuando el elemento buscando se encuentra en la posición n del array o no existe.
#
# - Comparaciones n + 1
# - Retorno: 1
#
# $$
# T_{peor}(n) = n + 1
# $$
#
# Eliminando constantes:
#
# $$
# T_{peor}(n) \in \Theta(n)
# $$
#
# # Caso promedio
# Si el elemento buscado se encuentra en la posición k, se realizan k + 1 comparaciones.
#
# El elemento puede estar en cualquiera de las n posiciones del array, entonces:
# $$
# T_{prom}(n) = \frac{1}{n}\sum_{k=0}^{n-1}(k+1)
# $$
#
# Sabemos que:
# $$1 + 2 + 3 + \dots + n = \frac{n(n+1)}{2}
# $$
#
# Entonces:
#
# $$
# T_{prom}(n) = \frac{1}{n} \cdot \frac{n(n+1)}{2}
# $$
#
#
# Simplificando:
#
# $$
# T_{prom}(n) = \frac{n+1}{2}
# $$
#
# Por lo tanto:
#
# $$
# T_{prom}(n) \in \Theta(n)
# $$
#
# # Orden de complejidad al que pertenece
# La búsqueda lineal pertenece al orden de complejidad lineal:
#
# $$
# O(n)
# $$

# %% [markdown]
# # Ejercicio 2: Complejidad Logarítmica O(log n) — Búsqueda Binaria

# %%
def busqueda_binaria(arr, objetivo):
    izquierda = 0
    derecha = len(arr) - 1
    contador = 0

    while izquierda <= derecha:
        contador += 1
        medio = (izquierda + derecha) // 2

        if arr[medio] == objetivo:
            return contador
        elif arr[medio] < objetivo:
            izquierda = medio + 1
        else:
            derecha = medio - 1

    return contador

# %% [markdown]
# ## Mejor caso
# Ocurre cuando el elemento buscado se encuentra en la mitad del array, en la primera iteración.
#
# $$
# T_{mejor}(n) \in \Theta(1)
# $$
#
# ## Peor caso
# Ocurre cuando el elemento no está o se encuentra en el último nivel de las divisiones del array.
#
# En cada iteración el tamaño del problema se reduce a la mitad:
#
# $$
# \frac{n}{2^k}
# $$
#
# El algoritmo termina cuando el tamaño se reduce a 1:
#
# $$
# \frac{n}{2^k} = 1
# $$
#
# Entonces:
#
# $$n = 2^k$$
#
# Aplicando logaritmo base 2 de ambos lados:
#
# $$k = \log_2(n)$$
#
# Ahora para el peor caso:
#
# $$
# T_{peor}(n) = a\log_2(n) + b
# $$
# \
# ($a$ son las operaciones dentro del while, que se realizarán $log_2(n)$ veces, $b$ son las operaciones que se realizan antes y después del while, se realizan 1 sola vez cada una)
#
#
# Eliminando constantes:
#
# $$
# T_{peor}(n) \in \Theta(\log n)
# $$
#
# ## Caso promedio
#
# En promedio también se requieren aproximadamente $ \log(n) $ iteraciones.
#
# $$
# T_{prom}(n) \in \Theta(\log n)
# $$
#
# ##Orden de complejidad al que pertenece
#
# La búsqueda binaria pertenece al orden de complejidad:
#
# $$
# O(\log n)
# $$

# %% [markdown]
# # Ejercicio 3: Complejidad Cuadrática O(n²) - Ordenamiento Burbuja

# %%
def burbuja(arr):
    n = len(arr)
    contador = 0
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            contador += 1
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return contador

# %% [markdown]
# ## Mejor caso
# Si el array ya está ordenado, solo se recorre una vez.
# \
# La operación principal es $ arr[j] > arr[j + 1].$
#
# $$
# T_{mejor}(n) = n-1
# $$
#
# $$
# T_{mejor}(n) \in \Theta(n)
# $$
#
# ##Peor caso
# Posiciones del array en orden inverso (descendente).
# El número total de comparaciones está dado por:
#
# $$
# T(n) = \sum_{i=0}^{n-1} (n - i - 1)
# $$
# Se recorre el array la mayor cantidad de veces posible, entonces:
# $$
# T_{peor}(n) = \frac{n(n-1)}{2}
# $$
#
# $$
# T_{peor}(n) \in \Theta(n^2)
# $$
#
# ## Caso promedio
#
# El número de comparaciones no depende del orden del array, por lo tanto:
#
# $$
# T_{prom}(n) = \frac{n(n-1)}{2}
# $$
#
# $$
# T_{prom}(n) \in \Theta(n^2)
# $$
#
# ## Orden de complejidad al que pertenece
# El ordenamiento burbuja pertenece al orden de complejidad:
#
# $$
# O(n^2)
# $$

# %% [markdown]
# ## Ejercicio 4: Complejidad Cúbica O(n³) - Multiplicación de Matrices

# %%
def mult_matrices(A, B):
    n = len(A)
    contador = 0
    C = [[0 for _ in range(n)] for _ in range(n)]

    for i in range(n):
        for j in range(n):
            suma = 0
            for k in range(n):
                contador += 1
                suma += A[i][k] * B[k][j]
            C[i][j] = suma

    return contador

# %% [markdown]
# La operación dominante se realiza en el bucle interno:
#
# $$
# suma \mathrel{+}= A[i][k]\cdot B[k][j]
# $$
#
# Conteo de iteraciones:
# - El bucle \(i\) se ejecuta \(n\) veces.
# - El bucle \(j\) se ejecuta \(n\) veces por cada \(i\).
# - El bucle \(k\) se ejecuta \(n\) veces por cada par \((i,j)\).
# \
#
#
# $$
# n \cdot n \cdot n = n^3
# $$
#
# Si las operaciones dentro de cada operación cuestan \(c\):
#
# $$
# T(n) = c\,n^3 + b
# $$
#
# Por lo tanto:
#
# $$
# T(n) \in \Theta(n^3)
# $$
#
# ## Casos
#
# $$
# n \cdot n \cdot n = n^3
# $$
#
# Si las operaciones dentro de cada iteración cuestan \(c\):
#
# $$
# T(n) = c\,n^3 + b
# $$
#
# Por lo tanto:
# $$
# T(n) \in \Theta(n^3)
# $$
#
# ## Orden del complejidad al que pertenece
# La multiplicación de matrices pertenece al orden de complejidad:
# $$\Theta(n^3)$$

# %% [markdown]
# ## Ejercicio 5: Análisis Combinado

# %%
from IPython.display import Image
Image("imagen1.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1288         if self.embed:
#    1289             mimetype = self._mimetype
# -> 1290             data, metadata = self._data_and_metadata(always_both=True)
#    1291             if metadata:
#    1292                 metadata = {mimetype: metadata}
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'imagen1.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_png_(self)
#    1318     def _repr_png_(self):
#    1319         if self.embed and self.format == self._FMT_PNG:
# -> 1320             return self._data_and_metadata()
#    1321
#    1322     def _repr_jpeg_(self):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'imagen1.png'

# %% [markdown]
# # Método del contador
# ## Segmento 1
# El ciclo se ejecuta 100 veces:
#
# $$
# C_1 = 100
# $$
#
# ---
#
# ## Segmento 2
#
# Dos bucles anidados:
#
# - El bucle externo se ejecuta \(n\) veces.
# - El bucle interno se ejecuta \(n\) veces por cada iteración del externo.
#
# Total:
#
# $$
# C_2 = n \cdot n = n^2
# $$
#
# ---
# ## Segmento 3
#
# El ciclo se ejecuta \(n\) veces:
#
# $$
# C_3 = n
# $$

# %% [markdown]
# # Expresión Completa
#
# Sumamos los tres segmentos:
#
# $$
# T(n) = 100 + n^2 + n
# $$
#
# Aplicando la regla de la suma, el término dominante es:
#
# $$
# n^2
# $$
# Por lo tanto:
#
# $$
# T(n) \in \Theta(n^2)
# $$
#
# ## Orden de complejidad final:
#
# $$
# O(n^2)
# $$

# %% [markdown]
# ## Parte experimental:

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# #Funcion tabla:

# %%
import math
import pandas as pd

def _normalizar_contador(contador):
    if isinstance(contador, (int, float)):
        return int(contador)

    if isinstance(contador, list):
        if len(contador) > 0 and isinstance(contador[0], list):
            return sum(len(fila) for fila in contador)
        return len(contador)

    try:
        return int(contador)
    except:
        return None


def construir_tabla(resultados):
    """
    resultados: lista de dicts con llaves:
      Algoritmo, n, Tiempo (s), Contador
    """
    filas = []
    for r in resultados:
        n = r["n"]
        t = r["Tiempo (s)"]
        c = _normalizar_contador(r["Contador"])

        filas.append({
            "Algoritmo": r["Algoritmo"],
            "n": n,
            "Tiempo (s)": t,
            "Contador": c,
            "Tiempo/n": t / n,
            "Tiempo/n²": t / (n**2),
            "Tiempo/n³": t / (n**3),
            "Tiempo/log n": t / (math.log(n) if n > 1 else float("nan"))
        })

    df = pd.DataFrame(filas, columns=[
        "Algoritmo","n","Tiempo (s)","Contador","Tiempo/n","Tiempo/n²","Tiempo/n³","Tiempo/log n"
    ])

    df2 = df.copy()
    for alg in df2["Algoritmo"].unique():
        idx = df2.index[df2["Algoritmo"] == alg].tolist()
        for i in idx[1:]:
            df2.loc[i, "Algoritmo"] = ""
    return df2

# %% [markdown]
# #Funcion medir_tiempo:

# %%
#Implementación:
import time
import matplotlib.pyplot as plt
import random
import math

def medir_tiempo(algoritmos, *args):
  inicio = time.perf_counter()
  contador = algoritmos(*args)
  fin = time.perf_counter()
  return fin - inicio, contador

# %% [markdown]
# # Experimento busqueda lineal O(n):

# %%
tamaños = [10, 50, 100, 500, 1000, 5000]

tiempos_experimentales = []
contadores = []

resultados_tabla = []

for n in tamaños:

    tiempos = []
    contador_rep = None

    for _ in range(5):
        arr = [random.randint(1, 10000) for _ in range(n)]
        objetivo = arr[-1]

        tiempo, contador = medir_tiempo(busqueda_lineal, arr, objetivo)
        tiempos.append(tiempo)
        contador_rep = contador

    tiempo_promedio = sum(tiempos) / 5

    tiempos_experimentales.append(tiempo_promedio)
    contadores.append(contador_rep)

    if n in [100, 1000, 5000]:
        resultados_tabla.append({
            "Algoritmo": "Lineal",
            "n": n,
            "Tiempo (s)": tiempo_promedio,
            "Contador": contador_rep
        })

    print(f"n = {n}")
    print(f"Tiempo promedio = {tiempo_promedio}")
    print(f"Contador = {contador_rep}")
    print("-----------")
# Out:
# n = 10
# Tiempo promedio = 1.2960000276507345e-06
# Contador = 10
# -----------
# n = 50
# Tiempo promedio = 2.570000015111873e-06
# Contador = 50
# -----------
# n = 100
# Tiempo promedio = 3.982000043833977e-06
# Contador = 100
# -----------
# n = 500
# Tiempo promedio = 2.5381400064361515e-05
# Contador = 500
# -----------
# n = 1000
# Tiempo promedio = 5.958700003247941e-05
# Contador = 1000
# -----------
# n = 5000
# Tiempo promedio = 0.0003503196000565367
# Contador = 5000
# -----------

# %% [markdown]
# #Experimento Busqueda Binaria O(log(n))

# %%
tamaños_binaria = [10, 50, 100, 500, 1000, 2000, 5000]

tiempos_binaria = []
contadores_binaria = []

for n in tamaños_binaria:

    tiempos = []
    contador_rep = None

    for _ in range(5):
        arr = sorted([random.randint(1, 10000) for _ in range(n)])
        objetivo = arr[-1]

        tiempo, contador = medir_tiempo(busqueda_binaria, arr, objetivo)
        tiempos.append(tiempo)
        contador_rep = contador

    tiempo_promedio = sum(tiempos) / 5

    tiempos_binaria.append(tiempo_promedio)
    contadores_binaria.append(contador_rep)

    if n in [100, 1000, 5000]:
        resultados_tabla.append({
            "Algoritmo": "Binaria",
            "n": n,
            "Tiempo (s)": tiempo_promedio,
            "Contador": contador_rep
        })

    print(f"[Binaria] n = {n}")
    print(f"Tiempo promedio = {tiempo_promedio}")
    print(f"Contador = {contador_rep}")
    print("----------------------")
# Out:
# [Binaria] n = 10
# Tiempo promedio = 1.851599972724216e-06
# Contador = 4
# ----------------------
# [Binaria] n = 50
# Tiempo promedio = 9.94200036075199e-07
# Contador = 6
# ----------------------
# [Binaria] n = 100
# Tiempo promedio = 1.0542000381974503e-06
# Contador = 7
# ----------------------
# [Binaria] n = 500
# Tiempo promedio = 3.0438000521826323e-06
# Contador = 9
# ----------------------
# [Binaria] n = 1000
# Tiempo promedio = 3.10220002575079e-06
# Contador = 10
# ----------------------
# [Binaria] n = 2000
# Tiempo promedio = 3.5940000088885425e-06
# Contador = 11
# ----------------------
# [Binaria] n = 5000
# Tiempo promedio = 9.526999974696082e-06
# Contador = 12
# ----------------------

# %% [markdown]
# #Experimento ordenamiento burbuja (O(n^2))

# %%
tamaños_burbuja = [10, 50, 100, 200, 500, 1000, 2000]

tiempos_burbuja = []
contadores_burbuja = []

for n in tamaños_burbuja:

    tiempos = []
    contador_rep = None

    for _ in range(5):
        arr = [random.randint(1, 10000) for _ in range(n)]


        tiempo, contador = medir_tiempo(burbuja, arr.copy())
        tiempos.append(tiempo)
        contador_rep = contador

    tiempo_promedio = sum(tiempos) / 5

    tiempos_burbuja.append(tiempo_promedio)
    contadores_burbuja.append(contador_rep)

    if n in [100, 1000, 2000]:
        resultados_tabla.append({
            "Algoritmo": "Burbuja",
            "n": n,
            "Tiempo (s)": tiempo_promedio,
            "Contador": contador_rep
        })

    print(f"[Burbuja] n = {n}")
    print(f"Tiempo promedio = {tiempo_promedio}")
    print(f"Contador = {contador_rep}")
    print("----------------------")
# Out:
# [Burbuja] n = 10
# Tiempo promedio = 9.470399982092204e-06
# Contador = 42
# ----------------------
# [Burbuja] n = 50
# Tiempo promedio = 0.00021179899999879126
# Contador = 1189
# ----------------------
# [Burbuja] n = 100
# Tiempo promedio = 0.0008353451999482786
# Contador = 4830
# ----------------------
# [Burbuja] n = 200
# Tiempo promedio = 0.0023068065999268584
# Contador = 19710
# ----------------------
# [Burbuja] n = 500
# Tiempo promedio = 0.013975469800016072
# Contador = 124120
# ----------------------
# [Burbuja] n = 1000
# Tiempo promedio = 0.1284917497999686
# Contador = 497904
# ----------------------
# [Burbuja] n = 2000
# Tiempo promedio = 0.8713082044000657
# Contador = 1996585
# ----------------------

# %% [markdown]
# #Experimento Matrices O(n^3)

# %%
tamaños_matrices = [10, 20, 30, 50, 70, 100]

tiempos_matrices = []
contadores_matrices = []

for n in tamaños_matrices:

    tiempos = []
    contador_rep = None

    for _ in range(5):
        A = [[random.randint(1,10) for _ in range(n)] for _ in range(n)]
        B = [[random.randint(1,10) for _ in range(n)] for _ in range(n)]

        tiempo, contador = medir_tiempo(mult_matrices, A, B)
        tiempos.append(tiempo)
        contador_rep = contador

    tiempo_promedio = sum(tiempos) / 5

    tiempos_matrices.append(tiempo_promedio)
    contadores_matrices.append(contador_rep)

    if n in [10, 30, 50]:
        resultados_tabla.append({
            "Algoritmo": "Matrices",
            "n": n,
            "Tiempo (s)": tiempo_promedio,
            "Contador": contador_rep
        })

    print(f"[Matrices] n = {n}")
    print(f"Tiempo promedio = {tiempo_promedio}")
    print(f"Contador = {contador_rep}")
    print("----------------------")
# Out:
# [Matrices] n = 10
# Tiempo promedio = 0.0001834165999753168
# Contador = 1000
# ----------------------
# [Matrices] n = 20
# Tiempo promedio = 0.0035544188000130815
# Contador = 8000
# ----------------------
# [Matrices] n = 30
# Tiempo promedio = 0.010996778000026098
# Contador = 27000
# ----------------------
# [Matrices] n = 50
# Tiempo promedio = 0.018863854999926842
# Contador = 125000
# ----------------------
# [Matrices] n = 70
# Tiempo promedio = 0.04796369420005249
# Contador = 343000
# ----------------------
# [Matrices] n = 100
# Tiempo promedio = 0.23293193680001423
# Contador = 1000000
# ----------------------

# %%
df = construir_tabla(resultados_tabla)
df
# Out:
#    Algoritmo     n  Tiempo (s)  Contador      Tiempo/n     Tiempo/n²  \
# 0     Lineal   100    0.000004       100  3.982000e-08  3.982000e-10
# 1             1000    0.000060      1000  5.958700e-08  5.958700e-11
# 2             5000    0.000350      5000  7.006392e-08  1.401278e-11
# 3    Binaria   100    0.000001         7  1.054200e-08  1.054200e-10
# 4             1000    0.000003        10  3.102200e-09  3.102200e-12
# 5             5000    0.000010        12  1.905400e-09  3.810800e-13
# 6    Burbuja   100    0.000835      4830  8.353452e-06  8.353452e-08
# 7             1000    0.128492    497904  1.284917e-04  1.284917e-07
# 8             2000    0.871308   1996585  4.356541e-04  2.178271e-07
# 9   Matrices    10    0.000183      1000  1.834166e-05  1.834166e-06
# 10              30    0.010997     27000  3.665593e-04  1.221864e-05
# 11              50    0.018864    125000  3.772771e-04  7.545542e-06
#
#        Tiempo/n³  Tiempo/log n
# 0   3.982000e-12  8.646803e-07
# 1   5.958700e-14  8.626102e-06
# 2   2.802557e-15  4.113087e-05
# 3   1.054200e-12  2.289166e-07
# 4   3.102200e-15  4.490895e-07
# 5   7.621600e-17  1.118561e-06
# 6   8.353452e-10  1.813929e-04
# 7   1.284917e-10  1.860109e-02
# 8   1.089135e-10  1.146322e-01
# 9   1.834166e-07  7.965682e-05
# 10  4.072881e-07  3.233208e-03
# 11  1.509108e-07  4.822020e-03
